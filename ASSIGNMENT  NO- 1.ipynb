# %%
pip install xlrd

# %%
import pandas as pd
import xlrd
data=pd.read_excel(r"C:\Users\SANDRA\Downloads\data.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data.loc[:,].mean()
# Out:
# C:\Users\SANDRA\AppData\Local\Temp\ipykernel_11920\747433363.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,].mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.mean(axis=0)
# Out:
# C:\Users\SANDRA\AppData\Local\Temp\ipykernel_11920\2773904261.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean(axis=0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
### there are 150 entries and 150 non null values. no null values present

# %%
import matplotlib.pyplot as plt                            ###scatter plot shows the relation between SL and PL of iris flower                         
plt.scatter(data["SL"], data["PL"],alpha=1)
plt.xlabel('Sepel length')
plt.ylabel('petal length')
plt.title('Scatter plot of Sepel length Vs petal length')
plt.show()

# %%
import pandas as pd
import xlrd
data=pd.read_excel(r"C:\Users\SANDRA\Downloads\data.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt                                       
plt.hist(data["SL"],bins=10, edgecolor='k')
plt.xlabel('Sepel length')
plt.title('histogram of Sepel length')
plt.show()

# %%
import matplotlib.pyplot as plt                                       
plt.boxplot(data["PL"],vert=False)
plt.xlabel('petal length')
plt.title('Box plot of petal length')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(data['SL'])
# Out:
# <Axes: ylabel='SL'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_excel(r"C:\Users\SANDRA\Downloads\data.xls")

# %%
iris["Classification"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
iris.plot(kind="scatter",x="PL", y= "PW").set(title="SCATTER PLOT- PL vs PW")
# Out:
# [Text(0.5, 1.0, 'SCATTER PLOT- PL vs PW')]

# %%
sns.jointplot(x="SL",y="PL", data=iris,color="g",hue="Classification")     ###joint plot of SL vs PL,scatterplot and histogram combined together,iris versicolor and iris verginica are little similar bus iris setosa is different from others

# %%
sns.boxplot(x="Classification", y="PL",data=iris).set(title=" BOX PLOT")      # analysis of 3 species with respect to PL,also te median value of data of each species
# Out:
# [Text(0.5, 1.0, ' BOX PLOT')]

# %%
sns.pairplot(iris, hue="Classification", size=3).add_legend().set(title=" PAIR PLOT")
# Out:
# C:\Users\SANDRA\New folder\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lineplot(x="SL",y="PL", data=iris,hue="Classification").set(title="SL vs PL-Line plot")
# Out:
# [Text(0.5, 1.0, 'SL vs PL-Line plot')]

# %%
sns.lineplot(x="Classification",y="SW", data=iris, marker="*",markerfacecolor="r",markersize=20).set(title="variation of SW of each species")
# Out:
# [Text(0.5, 1.0, 'variation of SW of each species')]
